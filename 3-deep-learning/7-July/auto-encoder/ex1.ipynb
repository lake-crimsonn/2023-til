# %%
from diffusers import DiffusionPipeline

pipeline = DiffusionPipeline.from_pretrained("lambdalabs/sd-image-variations-diffusers")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1086 in   │
# │ _get_module                                                                                      │
# │                                                                                                  │
# │   1083 │                                                                                         │
# │   1084 │   def _get_module(self, module_name: str):                                              │
# │   1085 │   │   try:                                                                              │
# │ ❱ 1086 │   │   │   return importlib.import_module("." + module_name, self.__name__)              │
# │   1087 │   │   except Exception as e:                                                            │
# │   1088 │   │   │   raise RuntimeError(                                                           │
# │   1089 │   │   │   │   f"Failed to import {self.__name__}.{module_name} because of the followin  │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\importlib\__init__.py:127 in import_module                 │
# │                                                                                                  │
# │   124 │   │   │   if character != '.':                                                           │
# │   125 │   │   │   │   break                                                                      │
# │   126 │   │   │   level += 1                                                                     │
# │ ❱ 127 │   return _bootstrap._gcd_import(name[level:], package, level)                            │
# │   128                                                                                            │
# │   129                                                                                            │
# │   130 _RELOADING = {}                                                                            │
# │ in _gcd_import:1030                                                                              │
# │ in _find_and_load:1007                                                                           │
# │ in _find_and_load_unlocked:986                                                                   │
# │ in _load_unlocked:680                                                                            │
# │ in exec_module:850                                                                               │
# │ in _call_with_frames_removed:228                                                                 │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\models\clip\image_processing_cl │
# │ ip.py:22 in <module>                                                                             │
# │                                                                                                  │
# │    19 import numpy as np                                                                         │
# │    20                                                                                            │
# │    21 from ...image_processing_utils import BaseImageProcessor, BatchFeature, get_size_dict      │
# │ ❱  22 from ...image_transforms import (                                                          │
# │    23 │   center_crop,                                                                           │
# │    24 │   convert_to_rgb,                                                                        │
# │    25 │   get_resize_output_image_size,                                                          │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\image_transforms.py:48 in       │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    45 │   import torch                                                                           │
# │    46                                                                                            │
# │    47 if is_tf_available():                                                                      │
# │ ❱  48 │   import tensorflow as tf                                                                │
# │    49                                                                                            │
# │    50 if is_flax_available():                                                                    │
# │    51 │   import jax.numpy as jnp                                                                │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\__init__.py:46 in         │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    43 from tensorflow.python import tf2 as _tf2                                                  │
# │    44 _tf2.enable()                                                                              │
# │    45                                                                                            │
# │ ❱  46 from ._api.v2 import __internal__                                                          │
# │    47 from ._api.v2 import __operators__                                                         │
# │    48 from ._api.v2 import audio                                                                 │
# │    49 from ._api.v2 import autodiff                                                              │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\__in │
# │ it__.py:13 in <module>                                                                           │
# │                                                                                                  │
# │   10 from . import dispatch                                                                      │
# │   11 from . import distribute                                                                    │
# │   12 from . import eager_context                                                                 │
# │ ❱ 13 from . import feature_column                                                                │
# │   14 from . import function                                                                      │
# │   15 from . import graph_util                                                                    │
# │   16 from . import mixed_precision                                                               │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\feat │
# │ ure_column\__init__.py:9 in <module>                                                             │
# │                                                                                                  │
# │    6 import sys as _sys                                                                          │
# │    7                                                                                             │
# │    8 from tensorflow.python.feature_column.feature_column_v2 import DenseColumn                  │
# │ ❱  9 from tensorflow.python.feature_column.feature_column_v2 import FeatureColumn                │
# │   10 from tensorflow.python.feature_column.feature_column_v2 import FeatureTransformationCach    │
# │   11 from tensorflow.python.feature_column.feature_column_v2 import SequenceDenseColumn          │
# │   12 from tensorflow.python.feature_column.feature_column_v2 import _StateManagerImpl as Stat    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ImportError: cannot import name 'FeatureColumn' from 'tensorflow.python.feature_column.feature_column_v2'
# (C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\feature_column\feature_column_v2.py)
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 from diffusers import DiffusionPipeline                                                      │
# │   2                                                                                              │
# │   3 pipeline = DiffusionPipeline.from_pretrained("lambdalabs/sd-image-variations-diffusers")     │
# │   4                                                                                              │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\__init__.py:60 in <module>         │
# │                                                                                                  │
# │    57 │   │   get_polynomial_decay_schedule_with_warmup,                                         │
# │    58 │   │   get_scheduler,                                                                     │
# │    59 │   )                                                                                      │
# │ ❱  60 │   from .pipelines import (                                                               │
# │    61 │   │   AudioPipelineOutput,                                                               │
# │    62 │   │   ConsistencyModelPipeline,                                                          │
# │    63 │   │   DanceDiffusionPipeline,                                                            │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\__init__.py:47 in        │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    44 except OptionalDependencyNotAvailable:                                                     │
# │    45 │   from ..utils.dummy_torch_and_transformers_objects import *  # noqa F403                │
# │    46 else:                                                                                      │
# │ ❱  47 │   from .alt_diffusion import AltDiffusionImg2ImgPipeline, AltDiffusionPipeline           │
# │    48 │   from .audioldm import AudioLDMPipeline                                                 │
# │    49 │   from .controlnet import (                                                              │
# │    50 │   │   StableDiffusionControlNetImg2ImgPipeline,                                          │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\alt_diffusion\__init__.p │
# │ y:32 in <module>                                                                                 │
# │                                                                                                  │
# │   29                                                                                             │
# │   30 if is_transformers_available() and is_torch_available():                                    │
# │   31 │   from .modeling_roberta_series import RobertaSeriesModelWithTransformation               │
# │ ❱ 32 │   from .pipeline_alt_diffusion import AltDiffusionPipeline                                │
# │   33 │   from .pipeline_alt_diffusion_img2img import AltDiffusionImg2ImgPipeline                 │
# │   34                                                                                             │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\alt_diffusion\pipeline_a │
# │ lt_diffusion.py:21 in <module>                                                                   │
# │                                                                                                  │
# │    18                                                                                            │
# │    19 import torch                                                                               │
# │    20 from packaging import version                                                              │
# │ ❱  21 from transformers import CLIPImageProcessor, XLMRobertaTokenizer                           │
# │    22                                                                                            │
# │    23 from diffusers.utils import is_accelerate_available, is_accelerate_version                 │
# │    24                                                                                            │
# │ in _handle_fromlist:1055                                                                         │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1077 in   │
# │ __getattr__                                                                                      │
# │                                                                                                  │
# │   1074 │   │   │   value = self._get_module(name)                                                │
# │   1075 │   │   elif name in self._class_to_module.keys():                                        │
# │   1076 │   │   │   module = self._get_module(self._class_to_module[name])                        │
# │ ❱ 1077 │   │   │   value = getattr(module, name)                                                 │
# │   1078 │   │   else:                                                                             │
# │   1079 │   │   │   raise AttributeError(f"module {self.__name__} has no attribute {name}")       │
# │   1080                                                                                           │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1076 in   │
# │ __getattr__                                                                                      │
# │                                                                                                  │
# │   1073 │   │   if name in self._modules:                                                         │
# │   1074 │   │   │   value = self._get_module(name)                                                │
# │   1075 │   │   elif name in self._class_to_module.keys():                                        │
# │ ❱ 1076 │   │   │   module = self._get_module(self._class_to_module[name])                        │
# │   1077 │   │   │   value = getattr(module, name)                                                 │
# │   1078 │   │   else:                                                                             │
# │   1079 │   │   │   raise AttributeError(f"module {self.__name__} has no attribute {name}")       │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1088 in   │
# │ _get_module                                                                                      │
# │                                                                                                  │
# │   1085 │   │   try:                                                                              │
# │   1086 │   │   │   return importlib.import_module("." + module_name, self.__name__)              │
# │   1087 │   │   except Exception as e:                                                            │
# │ ❱ 1088 │   │   │   raise RuntimeError(                                                           │
# │   1089 │   │   │   │   f"Failed to import {self.__name__}.{module_name} because of the followin  │
# │   1090 │   │   │   │   f" traceback):\n{e}"                                                      │
# │   1091 │   │   │   ) from e                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Failed to import transformers.models.clip.image_processing_clip because of the following error (look
# up to see its traceback):
# cannot import name 'FeatureColumn' from 'tensorflow.python.feature_column.feature_column_v2'
# (C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\feature_column\feature_column_v2.py)

# %%
from diffusers import StableDiffusionImageVariationPipeline
from PIL import Image
import torchvision.transforms as transforms

device = "cuda:0"
sd_pipe = StableDiffusionImageVariationPipeline.from_pretrained(
  "lambdalabs/sd-image-variations-diffusers",
  revision="v2.0",
  )
sd_pipe = sd_pipe.to(device)

im = Image.open("c:/data/air1")
tform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(
        (224, 224),
        interpolation=transforms.InterpolationMode.BICUBIC,
        antialias=False,
        ),
    transforms.Normalize(
      [0.48145466, 0.4578275, 0.40821073],
      [0.26862954, 0.26130258, 0.27577711]),
])
inp = tform(im).to(device).unsqueeze(0)

out = sd_pipe(inp, guidance_scale=3)
out["images"][0].save("C:/data/result.jpg")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1086 in   │
# │ _get_module                                                                                      │
# │                                                                                                  │
# │   1083 │                                                                                         │
# │   1084 │   def _get_module(self, module_name: str):                                              │
# │   1085 │   │   try:                                                                              │
# │ ❱ 1086 │   │   │   return importlib.import_module("." + module_name, self.__name__)              │
# │   1087 │   │   except Exception as e:                                                            │
# │   1088 │   │   │   raise RuntimeError(                                                           │
# │   1089 │   │   │   │   f"Failed to import {self.__name__}.{module_name} because of the followin  │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\importlib\__init__.py:127 in import_module                 │
# │                                                                                                  │
# │   124 │   │   │   if character != '.':                                                           │
# │   125 │   │   │   │   break                                                                      │
# │   126 │   │   │   level += 1                                                                     │
# │ ❱ 127 │   return _bootstrap._gcd_import(name[level:], package, level)                            │
# │   128                                                                                            │
# │   129                                                                                            │
# │   130 _RELOADING = {}                                                                            │
# │ in _gcd_import:1030                                                                              │
# │ in _find_and_load:1007                                                                           │
# │ in _find_and_load_unlocked:986                                                                   │
# │ in _load_unlocked:680                                                                            │
# │ in exec_module:850                                                                               │
# │ in _call_with_frames_removed:228                                                                 │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\models\clip\image_processing_cl │
# │ ip.py:22 in <module>                                                                             │
# │                                                                                                  │
# │    19 import numpy as np                                                                         │
# │    20                                                                                            │
# │    21 from ...image_processing_utils import BaseImageProcessor, BatchFeature, get_size_dict      │
# │ ❱  22 from ...image_transforms import (                                                          │
# │    23 │   center_crop,                                                                           │
# │    24 │   convert_to_rgb,                                                                        │
# │    25 │   get_resize_output_image_size,                                                          │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\image_transforms.py:48 in       │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    45 │   import torch                                                                           │
# │    46                                                                                            │
# │    47 if is_tf_available():                                                                      │
# │ ❱  48 │   import tensorflow as tf                                                                │
# │    49                                                                                            │
# │    50 if is_flax_available():                                                                    │
# │    51 │   import jax.numpy as jnp                                                                │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\__init__.py:46 in         │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    43 from tensorflow.python import tf2 as _tf2                                                  │
# │    44 _tf2.enable()                                                                              │
# │    45                                                                                            │
# │ ❱  46 from ._api.v2 import __internal__                                                          │
# │    47 from ._api.v2 import __operators__                                                         │
# │    48 from ._api.v2 import audio                                                                 │
# │    49 from ._api.v2 import autodiff                                                              │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\__in │
# │ it__.py:13 in <module>                                                                           │
# │                                                                                                  │
# │   10 from . import dispatch                                                                      │
# │   11 from . import distribute                                                                    │
# │   12 from . import eager_context                                                                 │
# │ ❱ 13 from . import feature_column                                                                │
# │   14 from . import function                                                                      │
# │   15 from . import graph_util                                                                    │
# │   16 from . import mixed_precision                                                               │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\feat │
# │ ure_column\__init__.py:9 in <module>                                                             │
# │                                                                                                  │
# │    6 import sys as _sys                                                                          │
# │    7                                                                                             │
# │    8 from tensorflow.python.feature_column.feature_column_v2 import DenseColumn                  │
# │ ❱  9 from tensorflow.python.feature_column.feature_column_v2 import FeatureColumn                │
# │   10 from tensorflow.python.feature_column.feature_column_v2 import FeatureTransformationCach    │
# │   11 from tensorflow.python.feature_column.feature_column_v2 import SequenceDenseColumn          │
# │   12 from tensorflow.python.feature_column.feature_column_v2 import _StateManagerImpl as Stat    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ImportError: cannot import name 'FeatureColumn' from 'tensorflow.python.feature_column.feature_column_v2'
# (C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\feature_column\feature_column_v2.py)
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱  1 from diffusers import StableDiffusionImageVariationPipeline                                 │
# │    2 from PIL import Image                                                                       │
# │    3 import torchvision.transforms as transforms                                                 │
# │    4                                                                                             │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\__init__.py:60 in <module>         │
# │                                                                                                  │
# │    57 │   │   get_polynomial_decay_schedule_with_warmup,                                         │
# │    58 │   │   get_scheduler,                                                                     │
# │    59 │   )                                                                                      │
# │ ❱  60 │   from .pipelines import (                                                               │
# │    61 │   │   AudioPipelineOutput,                                                               │
# │    62 │   │   ConsistencyModelPipeline,                                                          │
# │    63 │   │   DanceDiffusionPipeline,                                                            │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\__init__.py:47 in        │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    44 except OptionalDependencyNotAvailable:                                                     │
# │    45 │   from ..utils.dummy_torch_and_transformers_objects import *  # noqa F403                │
# │    46 else:                                                                                      │
# │ ❱  47 │   from .alt_diffusion import AltDiffusionImg2ImgPipeline, AltDiffusionPipeline           │
# │    48 │   from .audioldm import AudioLDMPipeline                                                 │
# │    49 │   from .controlnet import (                                                              │
# │    50 │   │   StableDiffusionControlNetImg2ImgPipeline,                                          │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\alt_diffusion\__init__.p │
# │ y:32 in <module>                                                                                 │
# │                                                                                                  │
# │   29                                                                                             │
# │   30 if is_transformers_available() and is_torch_available():                                    │
# │   31 │   from .modeling_roberta_series import RobertaSeriesModelWithTransformation               │
# │ ❱ 32 │   from .pipeline_alt_diffusion import AltDiffusionPipeline                                │
# │   33 │   from .pipeline_alt_diffusion_img2img import AltDiffusionImg2ImgPipeline                 │
# │   34                                                                                             │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\alt_diffusion\pipeline_a │
# │ lt_diffusion.py:21 in <module>                                                                   │
# │                                                                                                  │
# │    18                                                                                            │
# │    19 import torch                                                                               │
# │    20 from packaging import version                                                              │
# │ ❱  21 from transformers import CLIPImageProcessor, XLMRobertaTokenizer                           │
# │    22                                                                                            │
# │    23 from diffusers.utils import is_accelerate_available, is_accelerate_version                 │
# │    24                                                                                            │
# │ in _handle_fromlist:1055                                                                         │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1077 in   │
# │ __getattr__                                                                                      │
# │                                                                                                  │
# │   1074 │   │   │   value = self._get_module(name)                                                │
# │   1075 │   │   elif name in self._class_to_module.keys():                                        │
# │   1076 │   │   │   module = self._get_module(self._class_to_module[name])                        │
# │ ❱ 1077 │   │   │   value = getattr(module, name)                                                 │
# │   1078 │   │   else:                                                                             │
# │   1079 │   │   │   raise AttributeError(f"module {self.__name__} has no attribute {name}")       │
# │   1080                                                                                           │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1076 in   │
# │ __getattr__                                                                                      │
# │                                                                                                  │
# │   1073 │   │   if name in self._modules:                                                         │
# │   1074 │   │   │   value = self._get_module(name)                                                │
# │   1075 │   │   elif name in self._class_to_module.keys():                                        │
# │ ❱ 1076 │   │   │   module = self._get_module(self._class_to_module[name])                        │
# │   1077 │   │   │   value = getattr(module, name)                                                 │
# │   1078 │   │   else:                                                                             │
# │   1079 │   │   │   raise AttributeError(f"module {self.__name__} has no attribute {name}")       │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1088 in   │
# │ _get_module                                                                                      │
# │                                                                                                  │
# │   1085 │   │   try:                                                                              │
# │   1086 │   │   │   return importlib.import_module("." + module_name, self.__name__)              │
# │   1087 │   │   except Exception as e:                                                            │
# │ ❱ 1088 │   │   │   raise RuntimeError(                                                           │
# │   1089 │   │   │   │   f"Failed to import {self.__name__}.{module_name} because of the followin  │
# │   1090 │   │   │   │   f" traceback):\n{e}"                                                      │
# │   1091 │   │   │   ) from e                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Failed to import transformers.models.clip.image_processing_clip because of the following error (look
# up to see its traceback):
# cannot import name 'FeatureColumn' from 'tensorflow.python.feature_column.feature_column_v2'
# (C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\feature_column\feature_column_v2.py)

# %%
from diffusers import DiffusionPipeline
import torch

pipeline = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipeline.to("cuda")
pipeline("An image of a squirrel in Picasso style").images[0]
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1086 in   │
# │ _get_module                                                                                      │
# │                                                                                                  │
# │   1083 │                                                                                         │
# │   1084 │   def _get_module(self, module_name: str):                                              │
# │   1085 │   │   try:                                                                              │
# │ ❱ 1086 │   │   │   return importlib.import_module("." + module_name, self.__name__)              │
# │   1087 │   │   except Exception as e:                                                            │
# │   1088 │   │   │   raise RuntimeError(                                                           │
# │   1089 │   │   │   │   f"Failed to import {self.__name__}.{module_name} because of the followin  │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\importlib\__init__.py:127 in import_module                 │
# │                                                                                                  │
# │   124 │   │   │   if character != '.':                                                           │
# │   125 │   │   │   │   break                                                                      │
# │   126 │   │   │   level += 1                                                                     │
# │ ❱ 127 │   return _bootstrap._gcd_import(name[level:], package, level)                            │
# │   128                                                                                            │
# │   129                                                                                            │
# │   130 _RELOADING = {}                                                                            │
# │ in _gcd_import:1030                                                                              │
# │ in _find_and_load:1007                                                                           │
# │ in _find_and_load_unlocked:986                                                                   │
# │ in _load_unlocked:680                                                                            │
# │ in exec_module:850                                                                               │
# │ in _call_with_frames_removed:228                                                                 │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\models\clip\image_processing_cl │
# │ ip.py:22 in <module>                                                                             │
# │                                                                                                  │
# │    19 import numpy as np                                                                         │
# │    20                                                                                            │
# │    21 from ...image_processing_utils import BaseImageProcessor, BatchFeature, get_size_dict      │
# │ ❱  22 from ...image_transforms import (                                                          │
# │    23 │   center_crop,                                                                           │
# │    24 │   convert_to_rgb,                                                                        │
# │    25 │   get_resize_output_image_size,                                                          │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\image_transforms.py:48 in       │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    45 │   import torch                                                                           │
# │    46                                                                                            │
# │    47 if is_tf_available():                                                                      │
# │ ❱  48 │   import tensorflow as tf                                                                │
# │    49                                                                                            │
# │    50 if is_flax_available():                                                                    │
# │    51 │   import jax.numpy as jnp                                                                │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\__init__.py:46 in         │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    43 from tensorflow.python import tf2 as _tf2                                                  │
# │    44 _tf2.enable()                                                                              │
# │    45                                                                                            │
# │ ❱  46 from ._api.v2 import __internal__                                                          │
# │    47 from ._api.v2 import __operators__                                                         │
# │    48 from ._api.v2 import audio                                                                 │
# │    49 from ._api.v2 import autodiff                                                              │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\__in │
# │ it__.py:13 in <module>                                                                           │
# │                                                                                                  │
# │   10 from . import dispatch                                                                      │
# │   11 from . import distribute                                                                    │
# │   12 from . import eager_context                                                                 │
# │ ❱ 13 from . import feature_column                                                                │
# │   14 from . import function                                                                      │
# │   15 from . import graph_util                                                                    │
# │   16 from . import mixed_precision                                                               │
# │                                                                                                  │
# │ C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\feat │
# │ ure_column\__init__.py:9 in <module>                                                             │
# │                                                                                                  │
# │    6 import sys as _sys                                                                          │
# │    7                                                                                             │
# │    8 from tensorflow.python.feature_column.feature_column_v2 import DenseColumn                  │
# │ ❱  9 from tensorflow.python.feature_column.feature_column_v2 import FeatureColumn                │
# │   10 from tensorflow.python.feature_column.feature_column_v2 import FeatureTransformationCach    │
# │   11 from tensorflow.python.feature_column.feature_column_v2 import SequenceDenseColumn          │
# │   12 from tensorflow.python.feature_column.feature_column_v2 import _StateManagerImpl as Stat    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ImportError: cannot import name 'FeatureColumn' from 'tensorflow.python.feature_column.feature_column_v2'
# (C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\feature_column\feature_column_v2.py)
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 from diffusers import DiffusionPipeline                                                      │
# │   2 import torch                                                                                 │
# │   3                                                                                              │
# │   4 pipeline = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dty     │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\__init__.py:60 in <module>         │
# │                                                                                                  │
# │    57 │   │   get_polynomial_decay_schedule_with_warmup,                                         │
# │    58 │   │   get_scheduler,                                                                     │
# │    59 │   )                                                                                      │
# │ ❱  60 │   from .pipelines import (                                                               │
# │    61 │   │   AudioPipelineOutput,                                                               │
# │    62 │   │   ConsistencyModelPipeline,                                                          │
# │    63 │   │   DanceDiffusionPipeline,                                                            │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\__init__.py:47 in        │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    44 except OptionalDependencyNotAvailable:                                                     │
# │    45 │   from ..utils.dummy_torch_and_transformers_objects import *  # noqa F403                │
# │    46 else:                                                                                      │
# │ ❱  47 │   from .alt_diffusion import AltDiffusionImg2ImgPipeline, AltDiffusionPipeline           │
# │    48 │   from .audioldm import AudioLDMPipeline                                                 │
# │    49 │   from .controlnet import (                                                              │
# │    50 │   │   StableDiffusionControlNetImg2ImgPipeline,                                          │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\alt_diffusion\__init__.p │
# │ y:32 in <module>                                                                                 │
# │                                                                                                  │
# │   29                                                                                             │
# │   30 if is_transformers_available() and is_torch_available():                                    │
# │   31 │   from .modeling_roberta_series import RobertaSeriesModelWithTransformation               │
# │ ❱ 32 │   from .pipeline_alt_diffusion import AltDiffusionPipeline                                │
# │   33 │   from .pipeline_alt_diffusion_img2img import AltDiffusionImg2ImgPipeline                 │
# │   34                                                                                             │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\diffusers\pipelines\alt_diffusion\pipeline_a │
# │ lt_diffusion.py:21 in <module>                                                                   │
# │                                                                                                  │
# │    18                                                                                            │
# │    19 import torch                                                                               │
# │    20 from packaging import version                                                              │
# │ ❱  21 from transformers import CLIPImageProcessor, XLMRobertaTokenizer                           │
# │    22                                                                                            │
# │    23 from diffusers.utils import is_accelerate_available, is_accelerate_version                 │
# │    24                                                                                            │
# │ in _handle_fromlist:1055                                                                         │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1077 in   │
# │ __getattr__                                                                                      │
# │                                                                                                  │
# │   1074 │   │   │   value = self._get_module(name)                                                │
# │   1075 │   │   elif name in self._class_to_module.keys():                                        │
# │   1076 │   │   │   module = self._get_module(self._class_to_module[name])                        │
# │ ❱ 1077 │   │   │   value = getattr(module, name)                                                 │
# │   1078 │   │   else:                                                                             │
# │   1079 │   │   │   raise AttributeError(f"module {self.__name__} has no attribute {name}")       │
# │   1080                                                                                           │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1076 in   │
# │ __getattr__                                                                                      │
# │                                                                                                  │
# │   1073 │   │   if name in self._modules:                                                         │
# │   1074 │   │   │   value = self._get_module(name)                                                │
# │   1075 │   │   elif name in self._class_to_module.keys():                                        │
# │ ❱ 1076 │   │   │   module = self._get_module(self._class_to_module[name])                        │
# │   1077 │   │   │   value = getattr(module, name)                                                 │
# │   1078 │   │   else:                                                                             │
# │   1079 │   │   │   raise AttributeError(f"module {self.__name__} has no attribute {name}")       │
# │                                                                                                  │
# │ c:\Users\user\miniconda3\envs\gpu\lib\site-packages\transformers\utils\import_utils.py:1088 in   │
# │ _get_module                                                                                      │
# │                                                                                                  │
# │   1085 │   │   try:                                                                              │
# │   1086 │   │   │   return importlib.import_module("." + module_name, self.__name__)              │
# │   1087 │   │   except Exception as e:                                                            │
# │ ❱ 1088 │   │   │   raise RuntimeError(                                                           │
# │   1089 │   │   │   │   f"Failed to import {self.__name__}.{module_name} because of the followin  │
# │   1090 │   │   │   │   f" traceback):\n{e}"                                                      │
# │   1091 │   │   │   ) from e                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Failed to import transformers.models.clip.image_processing_clip because of the following error (look
# up to see its traceback):
# cannot import name 'FeatureColumn' from 'tensorflow.python.feature_column.feature_column_v2'
# (C:\Users\user\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\feature_column\feature_column_v2.py)
