# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.12.0

# %%
# %pip install git+https://github.com/tensorflow/docs

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots
# Out:
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/docs 'C:\Users\user\AppData\Local\Temp\pip-req-build-ndqo8npu'
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to c:\users\user\appdata\local\temp\pip-req-build-ndqo8npu
#   Resolved https://github.com/tensorflow/docs to commit 40881b6e9c65d3cd164b391de055aeb60d2f51af
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting astor (from tensorflow-docs==2023.5.26.9808)
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: absl-py in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from tensorflow-docs==2023.5.26.9808) (1.4.0)
# Requirement already satisfied: jinja2 in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from tensorflow-docs==2023.5.26.9808) (3.1.2)
# Collecting nbformat (from tensorflow-docs==2023.5.26.9808)
#   Using cached nbformat-5.9.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: protobuf>=3.12 in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from tensorflow-docs==2023.5.26.9808) (4.23.2)
# Collecting pyyaml (from tensorflow-docs==2023.5.26.9808)
#   Downloading PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
#      -------------------------------------- 151.6/151.6 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from jinja2->tensorflow-docs==2023.5.26.9808) (2.1.3)
# Collecting fastjsonschema (from nbformat->tensorflow-docs==2023.5.26.9808)
#   Using cached fastjsonschema-2.17.1-py3-none-any.whl (23 kB)
# Collecting jsonschema>=2.6 (from nbformat->tensorflow-docs==2023.5.26.9808)
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Requirement already satisfied: jupyter-core in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from nbformat->tensorflow-docs==2023.5.26.9808) (5.3.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from nbformat->tensorflow-docs==2023.5.26.9808) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==2023.5.26.9808) (23.1.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema>=2.6->nbformat->tensorflow-docs==2023.5.26.9808)
#   Downloading pyrsistent-0.19.3-cp39-cp39-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from jupyter-core->nbformat->tensorflow-docs==2023.5.26.9808) (3.6.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\miniconda3\envs\gpu\lib\site-packages (from jupyter-core->nbformat->tensorflow-docs==2023.5.26.9808) (305.1)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py): started
#   Building wheel for tensorflow-docs (setup.py): finished with status 'done'
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-2023.5.26.9808-py3-none-any.whl size=185059 sha256=2bf7481a28b4719d7e19d8f8b969e9a778580c1af50b65852357b0a423e209a4
#   Stored in directory: C:\Users\user\AppData\Local\Temp\pip-ephem-wheel-cache-5hufo0za\wheels\fc\f8\3b\5d21409a59cb1be9b1ade11f682039ced75b84de9dd6a0c8de
# Successfully built tensorflow-docs
# Installing collected packages: fastjsonschema, pyyaml, pyrsistent, astor, jsonschema, nbformat, tensorflow-docs
# Successfully installed astor-0.8.1 fastjsonschema-2.17.1 jsonschema-4.17.3 nbformat-5.9.0 pyrsistent-0.19.3 pyyaml-6.0 tensorflow-docs-2023.5.26.9808
# Note: you may need to restart the kernel to use updated packages.

# %%
from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')
# Out:
# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz
# 2816407858/2816407858 [==============================] - 193s 0us/step

# %%
FEATURES = 28

# %%
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_ds.batch(1000).take(1):
  print(features[0])
  plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset element_spec=(TensorSpec(shape=(28,), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.float32, name=None))>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                464
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4940,  binary_crossentropy:0.8582,  loss:0.8582,  val_accuracy:0.4850,  val_binary_crossentropy:0.8258,  val_loss:0.8258,
# ....................................................................................................
# Epoch: 100, accuracy:0.5920,  binary_crossentropy:0.6254,  loss:0.6254,  val_accuracy:0.5830,  val_binary_crossentropy:0.6237,  val_loss:0.6237,
# ....................................................................................................
# Epoch: 200, accuracy:0.6216,  binary_crossentropy:0.6114,  loss:0.6114,  val_accuracy:0.6150,  val_binary_crossentropy:0.6139,  val_loss:0.6139,
# ....................................................................................................
# Epoch: 300, accuracy:0.6451,  binary_crossentropy:0.6011,  loss:0.6011,  val_accuracy:0.6220,  val_binary_crossentropy:0.6058,  val_loss:0.6058,
# ....................................................................................................
# Epoch: 400, accuracy:0.6548,  binary_crossentropy:0.5952,  loss:0.5952,  val_accuracy:0.6250,  val_binary_crossentropy:0.6019,  val_loss:0.6019,
# ....................................................................................................
# Epoch: 500, accuracy:0.6527,  binary_crossentropy:0.5916,  loss:0.5916,  val_accuracy:0.6430,  val_binary_crossentropy:0.5989,  val_loss:0.5989,
# ....................................................................................................
# Epoch: 600, accuracy:0.6573,  binary_crossentropy:0.5901,  loss:0.5901,  val_accuracy:0.6570,  val_binary_crossentropy:0.5966,  val_loss:0.5966,
# ....................................................................................................
# Epoch: 700, accuracy:0.6716,  binary_crossentropy:0.5860,  loss:0.5860,  val_accuracy:0.6510,  val_binary_crossentropy:0.5949,  val_loss:0.5949,
# ....................................................................................................
# Epoch: 800, accuracy:0.6682,  binary_crossentropy:0.5835,  loss:0.5835,  val_accuracy:0.6540,  val_binary_crossentropy:0.5914,  val_loss:0.5914,
# ....................................................................................................
# Epoch: 900, accuracy:0.6738,  binary_crossentropy:0.5806,  loss:0.5806,  val_accuracy:0.6520,  val_binary_crossentropy:0.5898,  val_loss:0.5898,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6769,  binary_crossentropy:0.5787,  loss:0.5787,  val_accuracy:0.6590,  val_binary_crossentropy:0.5878,  val_loss:0.5878,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6799,  binary_crossentropy:0.5770,  loss:0.5770,  val_accuracy:0.6650,  val_binary_crossentropy:0.5864,  val_loss:0.5864,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6771,  binary_crossentropy:0.5766,  loss:0.5766,  val_accuracy:0.6590,  val_binary_crossentropy:0.5866,  val_loss:0.5866,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6807,  binary_crossentropy:0.5748,  loss:0.5748,  val_accuracy:0.6610,  val_binary_crossentropy:0.5858,  val_loss:0.5858,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6814,  binary_crossentropy:0.5735,  loss:0.5735,  val_accuracy:0.6750,  val_binary_crossentropy:0.5851,  val_loss:0.5851,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6815,  binary_crossentropy:0.5726,  loss:0.5726,  val_accuracy:0.6620,  val_binary_crossentropy:0.5849,  val_loss:0.5849,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6839,  binary_crossentropy:0.5716,  loss:0.5716,  val_accuracy:0.6640,  val_binary_crossentropy:0.5848,  val_loss:0.5848,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6862,  binary_crossentropy:0.5708,  loss:0.5708,  val_accuracy:0.6620,  val_binary_crossentropy:0.5848,  val_loss:0.5848,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6846,  binary_crossentropy:0.5698,  loss:0.5698,  val_accuracy:0.6590,  val_binary_crossentropy:0.5844,  val_loss:0.5844,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6888,  binary_crossentropy:0.5693,  loss:0.5693,  val_accuracy:0.6580,  val_binary_crossentropy:0.5841,  val_loss:0.5841,
# ....................................................................................................
# Epoch: 2000, accuracy:0.6865,  binary_crossentropy:0.5683,  loss:0.5683,  val_accuracy:0.6600,  val_binary_crossentropy:0.5840,  val_loss:0.5840,
# ....................................................................................................
# Epoch: 2100, accuracy:0.6877,  binary_crossentropy:0.5675,  loss:0.5675,  val_accuracy:0.6620,  val_binary_crossentropy:0.5841,  val_loss:0.5841,
# ....................................................................................................
# Epoch: 2200, accuracy:0.6898,  binary_crossentropy:0.5668,  loss:0.5668,  val_accuracy:0.6610,  val_binary_crossentropy:0.5844,  val_loss:0.5844,
# ....................................................................................................
# Epoch: 2300, accuracy:0.6893,  binary_crossentropy:0.5664,  loss:0.5664,  val_accuracy:0.6620,  val_binary_crossentropy:0.5844,  val_loss:0.5844,
# ....................................................................................................
# Epoch: 2400, accuracy:0.6914,  binary_crossentropy:0.5656,  loss:0.5656,  val_accuracy:0.6580,  val_binary_crossentropy:0.5849,  val_loss:0.5849,
# .................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 16)                464
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4932,  binary_crossentropy:0.7135,  loss:0.7135,  val_accuracy:0.4770,  val_binary_crossentropy:0.7014,  val_loss:0.7014,
# ....................................................................................................
# Epoch: 100, accuracy:0.6071,  binary_crossentropy:0.6224,  loss:0.6224,  val_accuracy:0.5840,  val_binary_crossentropy:0.6302,  val_loss:0.6302,
# ....................................................................................................
# Epoch: 200, accuracy:0.6371,  binary_crossentropy:0.6089,  loss:0.6089,  val_accuracy:0.6120,  val_binary_crossentropy:0.6186,  val_loss:0.6186,
# ....................................................................................................
# Epoch: 300, accuracy:0.6539,  binary_crossentropy:0.5934,  loss:0.5934,  val_accuracy:0.6380,  val_binary_crossentropy:0.5992,  val_loss:0.5992,
# ....................................................................................................
# Epoch: 400, accuracy:0.6702,  binary_crossentropy:0.5823,  loss:0.5823,  val_accuracy:0.6270,  val_binary_crossentropy:0.5946,  val_loss:0.5946,
# ....................................................................................................
# Epoch: 500, accuracy:0.6803,  binary_crossentropy:0.5741,  loss:0.5741,  val_accuracy:0.6510,  val_binary_crossentropy:0.5879,  val_loss:0.5879,
# ....................................................................................................
# Epoch: 600, accuracy:0.6816,  binary_crossentropy:0.5687,  loss:0.5687,  val_accuracy:0.6610,  val_binary_crossentropy:0.5844,  val_loss:0.5844,
# ....................................................................................................
# Epoch: 700, accuracy:0.6892,  binary_crossentropy:0.5642,  loss:0.5642,  val_accuracy:0.6620,  val_binary_crossentropy:0.5840,  val_loss:0.5840,
# ....................................................................................................
# Epoch: 800, accuracy:0.6910,  binary_crossentropy:0.5594,  loss:0.5594,  val_accuracy:0.6540,  val_binary_crossentropy:0.5853,  val_loss:0.5853,
# ....................................................................................................
# Epoch: 900, accuracy:0.6936,  binary_crossentropy:0.5571,  loss:0.5571,  val_accuracy:0.6540,  val_binary_crossentropy:0.5886,  val_loss:0.5886,
# ............................................................................................

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                1856
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4808,  binary_crossentropy:0.7319,  loss:0.7319,  val_accuracy:0.4650,  val_binary_crossentropy:0.6944,  val_loss:0.6944,
# ....................................................................................................
# Epoch: 100, accuracy:0.7126,  binary_crossentropy:0.5312,  loss:0.5312,  val_accuracy:0.6530,  val_binary_crossentropy:0.6135,  val_loss:0.6135,
# ....................................................................................................
# Epoch: 200, accuracy:0.7767,  binary_crossentropy:0.4405,  loss:0.4405,  val_accuracy:0.6340,  val_binary_crossentropy:0.6910,  val_loss:0.6910,
# ...................................................

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               14848
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 512)               262656
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dense_13 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5192,  binary_crossentropy:0.7908,  loss:0.7908,  val_accuracy:0.4660,  val_binary_crossentropy:0.6862,  val_loss:0.6862,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0023,  loss:0.0023,  val_accuracy:0.6820,  val_binary_crossentropy:1.8039,  val_loss:1.8039,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6770,  val_binary_crossentropy:2.4777,  val_loss:2.4777,
# ..................

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
#docs_infra: no_execute

# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Open an embedded TensorBoard viewer
# %tensorboard --logdir {logdir}/sizes
# Out:
#       <iframe id="tensorboard-frame-b4bf29352a3ae4e1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b4bf29352a3ae4e1");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
display.IFrame(
    src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97",
    width="100%", height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# WindowsPath('C:/Users/user/AppData/Local/Temp/tmpn4rljvcq/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001), # 0.001 * weight **2
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 512)               14848
#
#  dense_15 (Dense)            (None, 512)               262656
#
#  dense_16 (Dense)            (None, 512)               262656
#
#  dense_17 (Dense)            (None, 512)               262656
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5030,  binary_crossentropy:0.7855,  loss:2.2881,  val_accuracy:0.4810,  val_binary_crossentropy:0.6751,  val_loss:2.0964,
# ....................................................................................................
# Epoch: 100, accuracy:0.6607,  binary_crossentropy:0.5935,  loss:0.6164,  val_accuracy:0.6300,  val_binary_crossentropy:0.5863,  val_loss:0.6092,
# ....................................................................................................
# Epoch: 200, accuracy:0.6723,  binary_crossentropy:0.5812,  loss:0.6042,  val_accuracy:0.6540,  val_binary_crossentropy:0.5781,  val_loss:0.6011,
# ....................................................................................................
# Epoch: 300, accuracy:0.6810,  binary_crossentropy:0.5726,  loss:0.5964,  val_accuracy:0.6910,  val_binary_crossentropy:0.5779,  val_loss:0.6016,
# ....................................................................................................
# Epoch: 400, accuracy:0.6868,  binary_crossentropy:0.5666,  loss:0.5912,  val_accuracy:0.6880,  val_binary_crossentropy:0.5767,  val_loss:0.6014,
# ....................................................................................................
# Epoch: 500, accuracy:0.6978,  binary_crossentropy:0.5554,  loss:0.5816,  val_accuracy:0.6760,  val_binary_crossentropy:0.5737,  val_loss:0.6002,
# ..........................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 512)               14848
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_21 (Dense)            (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_22 (Dense)            (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_23 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5102,  binary_crossentropy:0.7892,  loss:0.7892,  val_accuracy:0.4780,  val_binary_crossentropy:0.6796,  val_loss:0.6796,
# ....................................................................................................
# Epoch: 100, accuracy:0.6646,  binary_crossentropy:0.5952,  loss:0.5952,  val_accuracy:0.6790,  val_binary_crossentropy:0.5779,  val_loss:0.5779,
# ....................................................................................................
# Epoch: 200, accuracy:0.6886,  binary_crossentropy:0.5583,  loss:0.5583,  val_accuracy:0.6830,  val_binary_crossentropy:0.5758,  val_loss:0.5758,
# ....................................................................................................
# Epoch: 300, accuracy:0.7273,  binary_crossentropy:0.5086,  loss:0.5086,  val_accuracy:0.6830,  val_binary_crossentropy:0.5992,  val_loss:0.5992,
# .........

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 512)               14848
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_25 (Dense)            (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_26 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_27 (Dense)            (None, 512)               262656
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_28 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5047,  binary_crossentropy:0.7955,  loss:0.9536,  val_accuracy:0.5130,  val_binary_crossentropy:0.6847,  val_loss:0.8421,
# ....................................................................................................
# Epoch: 100, accuracy:0.6525,  binary_crossentropy:0.6036,  loss:0.6329,  val_accuracy:0.6630,  val_binary_crossentropy:0.5861,  val_loss:0.6153,
# ....................................................................................................
# Epoch: 200, accuracy:0.6709,  binary_crossentropy:0.5880,  loss:0.6136,  val_accuracy:0.6770,  val_binary_crossentropy:0.5717,  val_loss:0.5973,
# ....................................................................................................
# Epoch: 300, accuracy:0.6724,  binary_crossentropy:0.5810,  loss:0.6092,  val_accuracy:0.6930,  val_binary_crossentropy:0.5648,  val_loss:0.5930,
# ....................................................................................................
# Epoch: 400, accuracy:0.6697,  binary_crossentropy:0.5797,  loss:0.6093,  val_accuracy:0.6940,  val_binary_crossentropy:0.5490,  val_loss:0.5786,
# ....................................................................................................
# Epoch: 500, accuracy:0.6727,  binary_crossentropy:0.5722,  loss:0.6040,  val_accuracy:0.6950,  val_binary_crossentropy:0.5550,  val_loss:0.5868,
# ....................................................................................................
# Epoch: 600, accuracy:0.6844,  binary_crossentropy:0.5646,  loss:0.5980,  val_accuracy:0.6910,  val_binary_crossentropy:0.5459,  val_loss:0.5792,
# ....................................................................................................
# Epoch: 700, accuracy:0.6886,  binary_crossentropy:0.5628,  loss:0.5978,  val_accuracy:0.7040,  val_binary_crossentropy:0.5416,  val_loss:0.5766,
# ....................................................................................................
# Epoch: 800, accuracy:0.6894,  binary_crossentropy:0.5599,  loss:0.5963,  val_accuracy:0.6920,  val_binary_crossentropy:0.5488,  val_loss:0.5852,
# ..........................

# %%
display.IFrame(
    src="https://tensorboard.dev/experiment/fGInKDo8TXes1z7HQku9mw/#scalars&_smoothingWeight=0.97",
    width = "100%",
    height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://tensorboard.dev/experiment/fGInKDo8TXes1z7HQku9mw/#scalars&_smoothingWeight=0.97"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
