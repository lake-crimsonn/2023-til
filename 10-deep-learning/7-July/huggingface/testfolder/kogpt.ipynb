# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM 

tokenizer = AutoTokenizer.from_pretrained(
  'kakaobrain/kogpt', revision='KoGPT6B-ryan1.5b-float16',  # or float32 version: revision=KoGPT6B-ryan1.5b
  bos_token='[BOS]', eos_token='[EOS]', unk_token='[UNK]', pad_token='[PAD]', mask_token='[MASK]'
)
model = AutoModelForCausalLM.from_pretrained(
  'kakaobrain/kogpt', revision='KoGPT6B-ryan1.5b-float16',  # or float32 version: revision=KoGPT6B-ryan1.5b
  pad_token_id=tokenizer.eos_token_id,
  torch_dtype='auto', low_cpu_mem_usage=True
).to(device='cuda', non_blocking=True)
_ = model.eval()

prompt = '인간처럼 생각하고, 행동하는 \'지능\'을 통해 인류가 이제까지 풀지 못했던'
with torch.no_grad():
  tokens = tokenizer.encode(prompt, return_tensors='pt').to(device='cuda', non_blocking=True)
  gen_tokens = model.generate(tokens, do_sample=True, temperature=0.8, max_length=64)
  generated = tokenizer.batch_decode(gen_tokens)[0]
  
print(generated)  # print: 인간처럼 생각하고, 행동하는 '지능'을 통해 인류가 이제까지 풀지 못했던 문제의 해답을 찾을 수 있을 것이다. 과학기술이 고도로 발달한 21세기를 살아갈 우리 아이들에게 가장 필요한 것은 사고력 훈련이다. 사고력 훈련을 통해, 세상
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\transformers\modeling_utils.py:463, in load_state_dict(checkpoint_file)
#     462 try:
# --> 463     return torch.load(checkpoint_file, map_location="cpu")
#     464 except Exception as e:
#
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\torch\serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     808                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 809         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     810 if weights_only:
#
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\torch\serialization.py:1172, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1171 unpickler.persistent_load = persistent_load
# -> 1172 result = unpickler.load()
#    1174 torch._utils._validate_loaded_sparse_tensors()
#
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\torch\serialization.py:1142, in _load.<locals>.persistent_load(saved_id)
#    1141     nbytes = numel * torch._utils._element_size(dtype)
# -> 1142     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1144 return typed_storage
#
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\torch\serialization.py:1112, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1110 name = f'data/{key}'
# -> 1112 storage = zip_file.get_storage_from_record(name, numel, torch.UntypedStorage)._typed_storage()._untyped_storage
#    1113 # TODO: Once we decide to break serialization FC, we can
#    1114 # stop wrapping with TypedStorage
#
# RuntimeError: [enforce fail at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10\core\impl\alloc_cpu.cpp:72] data. DefaultCPUAllocator: not enough memory: you tried to allocate 134217728 bytes.
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\transformers\modeling_utils.py:467, in load_state_dict(checkpoint_file)
#     466 with open(checkpoint_file) as f:
# --> 467     if f.read(7) == "version":
#     468         raise OSError(
#     469             "You seem to have cloned a repository without having git-lfs installed. Please install "
#     470             "git-lfs and run `git lfs install` followed by `git lfs pull` in the folder "
#     471             "you cloned."
#     472         )
#
# File c:\Users\user\miniconda3\envs\gpu2\lib\codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     321 data = self.buffer + input
# --> 322 (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323 # keep undecoded input until the next call
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 64: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 8
#       2 from transformers import AutoTokenizer, AutoModelForCausalLM
#       4 tokenizer = AutoTokenizer.from_pretrained(
#       5   'kakaobrain/kogpt', revision='KoGPT6B-ryan1.5b-float16',  # or float32 version: revision=KoGPT6B-ryan1.5b
#       6   bos_token='[BOS]', eos_token='[EOS]', unk_token='[UNK]', pad_token='[PAD]', mask_token='[MASK]'
#       7 )
# ----> 8 model = AutoModelForCausalLM.from_pretrained(
#       9   'kakaobrain/kogpt', revision='KoGPT6B-ryan1.5b-float16',  # or float32 version: revision=KoGPT6B-ryan1.5b
#      10   pad_token_id=tokenizer.eos_token_id,
#      11   torch_dtype='auto', low_cpu_mem_usage=True
#      12 ).to(device='cuda', non_blocking=True)
#      13 _ = model.eval()
#      15 prompt = '인간처럼 생각하고, 행동하는 \'지능\'을 통해 인류가 이제까지 풀지 못했던'
#
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\transformers\models\auto\auto_factory.py:484, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     482 elif type(config) in cls._model_mapping.keys():
#     483     model_class = _get_model_class(config, cls._model_mapping)
# --> 484     return model_class.from_pretrained(
#     485         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     486     )
#     487 raise ValueError(
#     488     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     489     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     490 )
#
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\transformers\modeling_utils.py:2604, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2601 if from_pt:
#    2602     if not is_sharded and state_dict is None:
#    2603         # Time to load the checkpoint
# -> 2604         state_dict = load_state_dict(resolved_archive_file)
#    2606     # set dtype to instantiate the model under:
#    2607     # 1. If torch_dtype is not None, we use that dtype
#    2608     # 2. If torch_dtype is "auto", we auto-detect dtype from the loaded state_dict, by checking its first
#    2609     #    weights entry that is of a floating type - we assume all floating dtype weights are of the same dtype
#    2610     # we also may have config.torch_dtype available, but we won't rely on it till v5
#    2611     dtype_orig = None
#
# File c:\Users\user\miniconda3\envs\gpu2\lib\site-packages\transformers\modeling_utils.py:479, in load_state_dict(checkpoint_file)
#     474             raise ValueError(
#     475                 f"Unable to locate the file {checkpoint_file} which is necessary to load this pretrained "
#     476                 "model. Make sure you have saved the model properly."
#     477             ) from e
#     478 except (UnicodeDecodeError, ValueError):
# --> 479     raise OSError(
#     480         f"Unable to load weights from pytorch checkpoint file for '{checkpoint_file}' "
#     481         f"at '{checkpoint_file}'. "
#     482         "If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True."
#     483     )
#
# OSError: Unable to load weights from pytorch checkpoint file for 'C:\Users\user/.cache\huggingface\hub\models--kakaobrain--kogpt\snapshots\fb0b3bc1855111d79181e775aad061907af4b493\pytorch_model.bin' at 'C:\Users\user/.cache\huggingface\hub\models--kakaobrain--kogpt\snapshots\fb0b3bc1855111d79181e775aad061907af4b493\pytorch_model.bin'. If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True.
